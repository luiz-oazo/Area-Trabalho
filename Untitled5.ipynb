# %%
import numpy as np
import pandas as pd

# %%
x = {
    "productCode": "ANTECIPACAO_COMISSAO_CORRETOR",
    "externalId": "1709324898631x607573062277815700",
    "transactionCode": "1673071746645x841512452985117700",
    "transactionValue": 570000,
    "transactionSubstepsCount": 4,
    "transactionDate": "2024-02-28",
    "transactionAddressStreet": "Rua Nilo Cordeiro Dutra",
    "transactionAddressNeighborhood": "Carvoeira",
    "transactionAddressNumber": "100",
    "transactionAddressComplement": "APT 404",
    "transactionAddressCity": "Florianópolis",
    "transactionAddressUF": "SC",
    "transactionAddressCEP": "88040650",
    "currentInstallment": 1,
    "totalInstallment": 1,
    "constructionYear": 2022,
    "companygroup": "Independente (não pertencente a rede)",
    "propertyTypology": "",
    "expectedValue": 500,
    "expectedDate": "2024-03-04T03:00:00.000Z",
    "paymentStructure": [
        {
            "forma_pagamento_nome": "Sinal e princípio de pagamento",
            "forma_pagamento_valor": 565000.00,
            "forma_pagamento_detalhes": "Concomitante ao ato, TED"
        },
        {
            "forma_pagamento_nome": "Parcela concomitante à escritura",
            "forma_pagamento_valor": 5000.00,
            "forma_pagamento_detalhes": "TED"
        }
    ],
    "contract_files": [
        {
            "nome": "Contrato de Compra e Venda - v01 - minuta",
            "url": "url.com.br/doc1",
            "data_upload": "12/02/2024"
        },
        {
            "nome": "Contrato de Compra e Venda - v01 - final assinado",
            "url": "url.com.br/doc2",
            "data_upload": "23/02/2024"
        }
    ],
    "property_registration_files": [
        {
            "nome": "matrícula 12.654 do 4o CRI visualização não certificada",
            "url": "url.com.br/matricula1",
            "data_upload": "12/02/2024"
        },
        {
            "nome": "matrícula 12.654 do 4o CRI Certidão Carimbada",
            "url": "url.com.br/matricula2",
            "data_upload": "23/02/2024"
        }
    ],
    "intermediary": {
        "name": "Gralha Imóveis",
        "type": "JURIDICA",
        "cpfCnpj": "18091083000137"
    },
    "contracted": {
        "name": "SEGUNDO ANDAR NEGÓCIOS IMOBILIÁRIOS LTDA.",
        "type": "JURIDICA",
        "cpfCnpj": "36658539000180"
    },
    "guarantees": [
        {
            "externalId": "1673071746645x841512452985117700",
            "guaranteeType": "CONTRATO_COMPRA_VENDA_IMOVEL",
            "description": "Comissão Intermediação Imóvel à UP EASY HOME APT 404 - 22147 - Rua Nilo Cordeiro Dutra, 100, APT 404, Carvoeira, Florianópolis, CEP 88040650. - - Credores desta fatura: Cristiano Bartz Sperb (R$10.750,00); CASA & CASA GESTÃO DE NEGÓCIOS IMOBILIÁRIOS",
            "totalValue": 570000,
            "contractDate": "2024-02-28",
            "depositValue": 565000,
            "depositDate": "2024-03-01",
            "totalCommission": 25000,
            "brokerCommission": 500,
            "billingUrl": "https://www.asaas.com/i/zng91sqpsh92hj6n",
            "dueDate": "2024-03-04",
            "brokerName": "SEGUNDO ANDAR NEGÓCIOS IMOBILIÁRIOS LTDA.",
            "brokerCpfCnpj": "36658539000180",
            "brokerAssociationDate": "2016-02-22",
            "brokerPreviousTransactions": 406,
            "agencyName": "Gralha Imóveis",
            "agencyCnpj": "18091083000137",
            "agencyPreviousTransactions": 585,
            "fiduciaryAlienation": False,
            "fiduciaryAlienationBankSlug": "",
            "parties": [
                {
                    "name": "CHAMONIX - NÚMERO UM IMÓVEIS LTDA",
                    "type": "VENDEDOR",
                    "cpfCnpj": "15425927000140"
                },
                {
                    "name": "ANITA CAMPOS ROCHA",
                    "type": "COMPRADOR",
                    "cpfCnpj": "84582987915"
                }
            ]
        }
    ]
}

# %%
x
# Out:
# {'productCode': 'ANTECIPACAO_COMISSAO_CORRETOR',
#  'externalId': '1709324898631x607573062277815700',
#  'transactionCode': '1673071746645x841512452985117700',
#  'transactionValue': 570000,
#  'transactionSubstepsCount': 4,
#  'transactionDate': '2024-02-28',
#  'transactionAddressStreet': 'Rua Nilo Cordeiro Dutra',
#  'transactionAddressNeighborhood': 'Carvoeira',
#  'transactionAddressNumber': '100',
#  'transactionAddressComplement': 'APT 404',
#  'transactionAddressCity': 'Florianópolis',
#  'transactionAddressUF': 'SC',
#  'transactionAddressCEP': '88040650',
#  'currentInstallment': 1,
#  'totalInstallment': 1,
#  'constructionYear': 2022,
#  'companygroup': 'Independente (não pertencente a rede)',
#  'propertyTypology': '',
#  'expectedValue': 500,
#  'expectedDate': '2024-03-04T03:00:00.000Z',
#  'paymentStructure': [{'forma_pagamento_nome': 'Sinal e princípio de pagamento',
#    'forma_pagamento_valor': 565000.0,
# ...

# %%
y = {'tipo': ['negocia', 'negocia', 'negocia'],
     'negociacao': ['sinal s', 'sinal n', 'compra_segura'],
     'peso': [1, -1, 2]
     }

# %%
y
# Out:
# {'tipo': ['negocia', 'negocia', 'negocia'],
#  'negociacao': ['sinal s', 'sinal n', 'compra_segura'],
#  'peso': [1, -1, 2]}

# %%
df = pd.DataFrame(y)

# %%
df
# Out:
#       tipo     negociacao  peso
# 0  negocia        sinal s     1
# 1  negocia        sinal n    -1
# 2  negocia  compra_segura     2
