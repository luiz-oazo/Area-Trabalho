# %%
nav = {"imob_pal":{"brazil":3,"state":3,"percent":1.5154064881270255E-6,"classification":3,"value":0.0984051146151232},"imob_rec":{"brazil":3,"state":3,"percent":0.0,"classification":3,"value":-0.033323570039664165},"endividamento":{"brazil":3,"state":3,"percent":0.0,"classification":3,"value":-2.1428583386206013},"liquidez_corrente":{"brazil":3,"state":3,"percent":0.0,"classification":3,"value":10.916861623468925},"ccl":{"brazil":3,"state":3,"percent":0.8420965680167786,"classification":3,"value":54682.76},"seca_II":{"brazil":3,"state":3,"percent":0.0,"classification":3,"value":-2.104353704713582},"seca_I":{"brazil":3,"state":3,"percent":0.0,"classification":3,"value":-2.0684679863410524},"comp_end":{"brazil":3,"state":1,"percent":0.0,"classification":1,"value":-0.844740878468994},"liq_geral":{"brazil":3,"state":3,"percent":0.0,"classification":3,"value":-0.09221919277933588},"corrente":{"brazil":3,"state":3,"percent":0.0,"classification":3,"value":0.10916861623468925},"ccp":{"brazil":3,"state":3,"percent":-0.24881173050918956,"classification":3,"value":-16156.95},"seca_III":{"brazil":3,"state":3,"percent":0.0,"classification":3,"value":-2.104353704713582}}

nav = {"equilibrio":{"classification":4,"value":-2334.9543391476914,"percent":0,"state":3,"brazil":3,"weight":5},"rlp":{"classification":3,"value":-201022.05,"percent":-0.5551885505073086,"state":3,"brazil":3,"weight":3},"margem_bruta":{"classification":3,"value":189.47630557852915,"percent":0,"state":3,"brazil":3,"weight":3},"custo_financeiro":{"classification":4,"value":-288948.62,"percent":-0.7980267115417794,"state":3,"brazil":3,"weight":2},"despesas":{"classification":4,"value":-435975.49,"percent":-1.2040898018392194,"state":3,"brazil":3,"weight":5},"ebitda":{"classification":4,"value":2479384.09,"percent":6.847635167773797,"state":3,"brazil":3,"weight":5},"imob_pal":{"classification":3,"value":0.16141630818162114,"percent":4.45804259620252e-7,"state":3,"brazil":3,"weight":3},"ap":{"classification":3,"value":-101175.7,"percent":-0.28,"state":3,"brazil":3,"weight":3},"imob_rec":{"classification":3,"value":0.1616268228220447,"percent":0,"state":3,"brazil":3,"weight":4},"margem_liquida":{"classification":3,"value":226.90859942344494,"percent":0,"state":3,"brazil":3,"weight":3},"carga_tributaria":{"classification":4,"value":-0.023095534785930568,"percent":0,"state":3,"brazil":3,"weight":1},"endividamento":{"classification":4,"value":-2.9767984268787346,"percent":0,"state":3,"brazil":3,"weight":3},"liquidez_corrente":{"classification":3,"value":-34.467578120532515,"percent":0,"state":3,"brazil":3,"weight":5},"ccl":{"classification":3,"value":-323785.6,"percent":-0.8942404971949061,"state":3,"brazil":3,"weight":5},"seca_II":{"classification":3,"value":-0.09372296120454977,"percent":0,"state":3,"brazil":3,"weight":4},"seca_I":{"classification":3,"value":-0.32514727337576965,"percent":0,"state":3,"brazil":3,"weight":3},"comp_end":{"classification":4,"value":0.9995624583086905,"percent":0,"state":3,"brazil":3,"weight":3},"margem_contribuicao":{"classification":3,"value":186.95752318623306,"percent":0,"state":3,"brazil":3,"weight":3},"liq_geral":{"classification":3,"value":-0.45226211610873734,"percent":0,"state":3,"brazil":3,"weight":4},"corrente":{"classification":3,"value":-0.34467578120532516,"percent":0,"state":3,"brazil":3,"weight":3},"custo_operacional":{"classification":4,"value":-950728.9500000001,"percent":-2.6257508948686756,"state":3,"brazil":3,"weight":4},"crescimento":{"classification":0,"value":0,"percent":0,"state":0,"brazil":0,"weight":5},"ccp":{"classification":3,"value":-324601.99,"percent":-0.8964952268663458,"state":3,"brazil":3,"weight":5},"seca_III":{"classification":3,"value":-0.03619811732840553,"percent":0,"state":3,"brazil":3,"weight":5}}

# %%
nav
# Out:
# {'equilibrio': {'classification': 4,
#   'value': -2334.9543391476914,
#   'percent': 0,
#   'state': 3,
#   'brazil': 3,
#   'weight': 5},
#  'rlp': {'classification': 3,
#   'value': -201022.05,
#   'percent': -0.5551885505073086,
#   'state': 3,
#   'brazil': 3,
#   'weight': 3},
#  'margem_bruta': {'classification': 3,
#   'value': 189.47630557852915,
#   'percent': 0,
#   'state': 3,
#   'brazil': 3,
#   'weight': 3},
#  'custo_financeiro': {'classification': 4,
#   'value': -288948.62,
#   'percent': -0.7980267115417794,
#   'state': 3,
#   'brazil': 3,
#   'weight': 2},
#  'despesas': {'classification': 4,
#   'value': -435975.49,
#   'percent': -1.2040898018392194,
#   'state': 3,
#   'brazil': 3,
#   'weight': 5},
#  'ebitda': {'classification': 4,
#   'value': 2479384.09,
#   'percent': 6.847635167773797,
#   'state': 3,
#   'brazil': 3,
#   'weight': 5},
#  'imob_pal': {'classification': 3,
#   'value': 0.16141630818162114,
#   'percent': 4.45804259620252e-07,
# ...

# %%
nav.get('xx')

# %%
for i, j in nav.items():
    print(i)
    
    for k, l in j.items():
        print(i, k, l)
# Out:
# equilibrio
# equilibrio classification 4
# equilibrio value -2334.9543391476914
# equilibrio percent 0
# equilibrio state 3
# equilibrio brazil 3
# equilibrio weight 5
# rlp
# rlp classification 3
# rlp value -201022.05
# rlp percent -0.5551885505073086
# rlp state 3
# rlp brazil 3
# rlp weight 3
# margem_bruta
# margem_bruta classification 3
# margem_bruta value 189.47630557852915
# margem_bruta percent 0
# margem_bruta state 3
# margem_bruta brazil 3
# margem_bruta weight 3
# custo_financeiro
# custo_financeiro classification 4
# custo_financeiro value -288948.62
# custo_financeiro percent -0.7980267115417794
# custo_financeiro state 3
# custo_financeiro brazil 3
# custo_financeiro weight 2
# despesas
# despesas classification 4
# despesas value -435975.49
# despesas percent -1.2040898018392194
# despesas state 3
# despesas brazil 3
# despesas weight 5
# ebitda
# ebitda classification 4
# ebitda value 2479384.09
# ebitda percent 6.847635167773797
# ebitda state 3
# ebitda brazil 3
# ...
